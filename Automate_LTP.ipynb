# %%
import schedule
import time
import requests
import pandas as pd
from datetime import datetime, timedelta, date
import pyodbc
from sqlalchemy import create_engine
import mysql.connector

# %%
def execute():
    # %run LTP.ipynb

# %%
schedule.every().day.at('23:30').do(execute)

while True:
    schedule.run_pending()
    time.sleep(10)
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /var/folders/b1/b6tfvntn1k3cvt9kyzby94gm0000gn/T/ipykernel_17326/2458107810.py:34
#      31 cursor.execute(query)
#      33 # Fetch all rows from the result set
# ---> 34 rows = cursor.fetchall()
#      36 # Get column names
#      37 column_names = [desc[0] for desc in cursor.description]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mysql/connector/cursor.py:882, in MySQLCursor.fetchall(self)
#     880 if not self._have_unread_result():
#     881     raise errors.InterfaceError("No result set to fetch from.")
# --> 882 (rows, eof) = self._connection.get_rows()
#     883 if self._nextrow[0]:
#     884     rows.insert(0, self._nextrow[0])
#
# ...
